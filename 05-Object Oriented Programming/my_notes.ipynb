# %% [markdown]
# # Object Oriented Programming

# %% [markdown]
# ## Structure of class

# %%
class NameOfClass():
    def __init__(self, param1, param2):
        self.param1 = param1
        self.param2 = param2
    
    def some_method(self):
        # perform some action
        print(self.param1)

# %% [markdown]
# * the parameter name passed in can be whatever, but it must be the same as the what the self.param1 is assigned to
# * self connects the object to the class.
#     self refers to the current object (instance) of the class

# %%
# In Python, everything is an object, including functions and classes.
mylist = [1, 2, 3]

# %%
myset = set()

# %%
type(mylist)
# Out:
# list

# %%
class Dog():
    def __init__(self, )

# %%
my_sample = Sample()

# %%
type(my_sample)
# Out:
# __main__.Sample
