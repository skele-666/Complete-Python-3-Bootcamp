# %% [markdown]
# # Decorators
# ## Building Manual Decorator

# %%
def func():
    return 1

# %%
func()
# Out:
# 1

# %%
func
# Out:
# <function __main__.func()>

# %%
def hello():
    return "Hello!"

# %%
greet = hello

# %%
greet()
# Out:
# 'Hello!'

# %%
# Is greet pointing to hello or its own function?
del hello

# %%
hello()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 hello()
#
# NameError: name 'hello' is not defined

# %%
greet()
# Out:
# 'Hello!'

# %%
# Even though we deleted the name hello, greet still points to the original function object. Functions are objects that can be passed into other objects.

# %%
def hello(name='Jose'):
    print('The hello() function has been executed')
    
    def greet():
        return '\t This is the greet() function inside hello!'
    
    def welcome():
        return '\t This is welcome() inside hello!'
    
    print("I am going to return a function!")
    
    if name == 'Jose':
        return greet
    else:
        return welcome

# %%
hello()
# Out:
# The hello() function has been executed
# I am going to return a function!
# <function __main__.hello.<locals>.greet()>

# %%
my_new_func = hello() # It is pointing to the greet function inside hello
# Out:
# The hello() function has been executed
# I am going to return a function!

# %%
my_new_func
# Out:
# <function __main__.hello.<locals>.greet()>

# %%
print(my_new_func())
# Out:
# 	 This is the greet() function inside hello!

# %%
def cool():
    def super_cool():
        return "I am very cool!"
    
    return super_cool

# %%
some_func = cool()

# %%
some_func
# Out:
# <function __main__.cool.<locals>.super_cool()>

# %%
def hello():
    return 'Hi, Jose!'

# %%
def other(some_def_func):
    print('Other code runs here!')
    print(some_def_func())

# %%
other(hello)
# Out:
# Other code runs here!
# Hi, Jose!

# %%
# Create new decorator
def new_decorator(original_func):
    def wrap_func():
        print('Some extra code, before the original function')
        original_func()
        print("Some extra code, after the original function!")
    
    return wrap_func

# %%
def func_needs_decorator():
    print("I want to be decorated!!")

# %%
func_needs_decorator()
# Out:
# I want to be decorated!!

# %%
new_decorator(func_needs_decorator)
# Out:
# <function __main__.new_decorator.<locals>.wrap_func()>

# %%
decorated_func = new_decorator(func_needs_decorator)

# %%
decorated_func()
# Out:
# Some extra code, before the original function
# I want to be decorated!!
# Some extra code, after the original function!

# %%
decorated_func
# Out:
# <function __main__.new_decorator.<locals>.wrap_func()>

# %%
# @new_decorator
def func_needs_decorator():
    print("I want to be decorated!!")

# %%
func_needs_decorator()
# Out:
# I want to be decorated!!
