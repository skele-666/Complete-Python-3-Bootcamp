# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Iterators and Generators Homework
#
# ### Problem 1
#
# Create a generator that generates the squares of numbers up to some number N.

# %%
def gensquares(N):
    for i in range(N):
        yield i**2

# %%
for x in gensquares(10):
    print(x)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %% [markdown]
# ### Problem 2
#
# Create a generator that yields "n" random numbers between a low and high number (that are inputs). <br>Note: Use the random library. For example:

# %%
import random
random.randint(1, 10)
# Out:
# 10

# %%
def rand_num(low, high, n):
    for i in range(n):
        yield random.randint(low, high)

# %%
for num in rand_num(1, 10, 12):
    print(num)
# Out:
# 5
# 4
# 4
# 2
# 7
# 6
# 9
# 1
# 4
# 4
# 10
# 6

# %% [markdown]
# ### Problem 3
#
# Use the iter() function to convert the string below into an iterator:

# %%
s = 'hello'

s_iter = iter(s)
print(s_iter)
next(s_iter)
# Out:
# ...
# 'h'

# %% [markdown]
# ### Problem 4
# Explain a use case for a generator using a yield statement where you would not want to use a normal function with a return statement.

# %% [markdown]
# A use case would be for processing large data sets. It would be more efficient to read one line of the data set at a time with yield, instead of having to read the entire file into a list and returning the entire list.

# %% [markdown]
# ### Extra Credit!
# Can you explain what *gencomp* is in the code below? (Note: We never covered this in lecture! You will have to do some Googling/Stack Overflowing!)

# %%
my_list = [1,2,3,4,5]

gencomp = (item for item in my_list if item > 3)

for item in gencomp:
    print(item)
# Out:
# 4
# 5

# %% [markdown]
# This code is like a list comprehension, but instead of finding all the items that satisfy the condition (in this case, if item > 3) and saving it into a list, it creates a generator object that you can iterate through to get each value in it. Technically, it has no length because it is just a generator object. Once you have gone through each element, you cannot reuse the generator without recreating it.

# %% [markdown]
# Hint: Google *generator comprehension*!
#
# # Great Job!
