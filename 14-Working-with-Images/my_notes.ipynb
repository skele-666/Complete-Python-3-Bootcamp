# %% [markdown]
# # Working with Images
# * With pillow library

# %%
from PIL import Image

# %%
mac = Image.open("example.jpg")

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.filename
# Out:
# 'example.jpg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %% [markdown]
# ## Cropping Images

# %%
mac.crop(box=(0, 0, 100, 100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
pencils = Image.open("pencils.jpg")

# %%
pencils
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1950x1300>

# %%
pencils.size
# Out:
# (1950, 1300)

# %%
# TOP PENCILS
x = 0
y = 0

w = 0.3 * 1950
h = 0.1 * 1300

# %%
pencils.crop((x, y, w, h))
# Out:
# <PIL.Image.Image image mode=RGB size=585x130>

# %%
# BOTTOM PENCILS
x = 0
y = 1100

w = 0.3 * 1950
h = 1300

# %%
pencils.crop((x, y, w, h))
# Out:
# <PIL.Image.Image image mode=RGB size=585x200>

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
halfway = 1993 / 2
x = halfway - 200
w = halfway + 200

y = 800
h = 1257

# %%
mac.crop((x, y, w, h))
# Out:
# <PIL.Image.Image image mode=RGB size=400x457>
