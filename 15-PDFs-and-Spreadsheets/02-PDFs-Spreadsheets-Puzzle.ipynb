# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # PDFs and Spreadsheets Puzzle Exercise
#
# Let's test your skills, the files needed for this puzzle exercise
#
# You will need to work with two files for this exercise and solve the following tasks:
#
# * Task One: Use Python to extract the Google Drive link from the .csv file. (Hint: Its along the diagonal from top left to bottom right).
# * Task Two: Download the PDF from the Google Drive link (we already downloaded it for you just in case you can't download from Google Drive) and find the phone number that is in the document. Note: There are different ways of formatting a phone number!

# %% [markdown]
# ## Task One: Grab the Google Drive Link from .csv File

# %%
# Import CSV library
import csv

# Open file
f = open("./Exercise_Files/find_the_link.csv", newline="", encoding="utf-8")

# %%
# Create CSV reader object
csv_data = csv.reader(f)

# %%
print(type(csv_data))
print(csv_data)
# Out:
# <class '_csv.reader'>
# ...

# %%
# Reformat into a python object (list of lists)
data_lines = list(csv_data)

# %%
print(type(data_lines))
# print(data_lines)
# Out:
# <class 'list'>

# %%
# Get the diagonal from top left to bottom right
link = []
for i in range(len(data_lines)):
    link.append(data_lines[i][i])

link = "".join(link)
print(link)
# Out:
# https://drive.google.com/open?id=1G6SEgg018UB4_4xsAJJ5TdzrhmXipr4Q

# %%
f.close()

# %% [markdown]
# ## Task Two: Download the PDF from the Google Drive link and find the phone number that is in the document.

# %%
# You should get this phone number
# 505 503 4455

# %%
# Import PDF library
import pypdf

# Open file
f = open("./Exercise_Files/Find_the_Phone_Number.pdf", mode="rb")

# %%
# Create PDF reader object
pdf_reader = pypdf.PdfReader(f)

# %%
print(type(pdf_reader))
print(pdf_reader)
# Out:
# <class 'pypdf._reader.PdfReader'>
# ...

# %%
num_pages = pdf_reader.get_num_pages()

# %%
num_pages
# Out:
# 17

# %%
# The working out that I didn't do...
pattern = r'\d{3}'
all_text = ''

for n in range(num_pages):
    page = pdf_reader.get_page(n)
    page_text = page.extract_text()
    
    all_text += f' {page_text}'

# print(all_text)

# %%
for match in re.finditer(pattern, all_text):
    print(match)
# Out:
# <re.Match object; span=(643, 646), match='000'>
# <re.Match object; span=(18143, 18146), match='000'>
# <re.Match object; span=(35643, 35646), match='000'>
# <re.Match object; span=(42624, 42627), match='505'>
# <re.Match object; span=(42628, 42631), match='503'>
# <re.Match object; span=(42632, 42635), match='445'>

# %%
all_text[42624:42627 + 10]
# Out:
# '505.503.4455.'

# %%
# Regex pattern
phone_pattern = r'\d{3}.\d{3}.\d{4}'

# Import Regex library
import re

# %%
# Loop through each page, extract text, find phone number in page
phone_number = ''
page_found = 0
for page in range(num_pages):
    page_text = pdf_reader.get_page(page).extract_text()
    
    match = re.search(phone_pattern, page_text)
    if match:
        phone_number = match.group()
        page_found = page
        break

print(f'Found the phone number {phone_number} at page {page_found}.')
# Out:
# Found the phone number 505.503.4455 at page 13.

# %%
f.close()
